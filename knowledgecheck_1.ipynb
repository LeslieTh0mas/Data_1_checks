# %%
import requests
import pandas as pd

# %% [markdown]
# I pulled in the data from an API then described.

# %%
r = requests.get("https://harry-potter-api-en.onrender.com/characters")
df = pd.read_json("https://harry-potter-api-en.onrender.com/characters") 
print (df)
df.describe()
# Out:
#     id                                character    nickname  hogwartsStudent  \
# 0    1                       Harry James Potter       Harry             True
# 1    2                    Hermione Jean Granger    Hermione             True
# 2    3                              Ron Weasley         Ron             True
# 3    4                             Fred Weasley        Fred             True
# 4    5                           George Weasley      George             True
# 5    6                             Bill Weasley        Bill             True
# 6    7                            Percy Weasley       Percy             True
# 7    8                          Charlie Weasley     Charlie             True
# 8    9                            Ginny Weasley       Ginny             True
# 9   10                            Molly Weasley       Molly             True
# 10  11                           Arthur Weasley      Arthur             True
# ...

# %% [markdown]
# I pulled in the data from an API. I wrangled the data to only show characters that were never a Howgarts student.

# %%
r = requests.get("https://harry-potter-api-en.onrender.com/characters")
df = pd.read_json("https://harry-potter-api-en.onrender.com/characters") 
df = df.loc[df['hogwartsStudent']== False,:]
print (df)
# Out:
#     id    character nickname  hogwartsStudent hogwartsHouse  interpretedBy  \
# 22  23  Argus Filch    Filch            False       ninguna  David Bradley
#
#    child                                              image
# 22    []  https://raw.githubusercontent.com/fedeperin/ha...

# %% [markdown]
# I pulled in data from an API. I wrangled the data to only show characters that were from house Slytherin and described the data.

# %%
r = requests.get("https://harry-potter-api-en.onrender.com/characters")
df = pd.read_json("https://harry-potter-api-en.onrender.com/characters") 
df = df.loc[df['hogwartsHouse']== 'Slytherin',]
print (df)
df.describe()
# Out:
#     id            character   nickname  hogwartsStudent hogwartsHouse  \
# 13  14         Draco Malfoy      Draco             True     Slytherin
# 19  20        Severus Snape      Snape             True     Slytherin
# 20  21  Bellatrix Lestrange      Bella             True     Slytherin
# 21  22       Lord Voldemort  Voldemort             True     Slytherin
#
#            interpretedBy              child  \
# 13            Tom Felton  [Scorpius Malfoy]
# 19          Alan Rickman                 []
# 20  Helena Bonham Carter           [Delphi]
# 21         Ralph Fiennes           [Delphi]
#
#                                                 image
# 13  https://raw.githubusercontent.com/fedeperin/ha...
# 19  https://raw.githubusercontent.com/fedeperin/ha...
# 20  https://raw.githubusercontent.com/fedeperin/ha...
# 21  https://raw.githubusercontent.com/fedeperin/ha...
#               id
# count   4.000000
# mean   19.250000
# std     3.593976
# min    14.000000
# 25%    18.500000
# ...

# %% [markdown]
# I pulled in data from an API. I wrangled the data to only show characters that were from house Gryffindor and described the data.

# %%
r = requests.get("https://harry-potter-api-en.onrender.com/characters")
df = pd.read_json("https://harry-potter-api-en.onrender.com/characters") 
df = df.loc[df['hogwartsHouse']== 'Gryffindor',]
print (df)
df.describe()
# Out:
#     id                                character    nickname  hogwartsStudent  \
# 0    1                       Harry James Potter       Harry             True
# 1    2                    Hermione Jean Granger    Hermione             True
# 2    3                              Ron Weasley         Ron             True
# 3    4                             Fred Weasley        Fred             True
# 4    5                           George Weasley      George             True
# 5    6                             Bill Weasley        Bill             True
# 6    7                            Percy Weasley       Percy             True
# 7    8                          Charlie Weasley     Charlie             True
# 8    9                            Ginny Weasley       Ginny             True
# 9   10                            Molly Weasley       Molly             True
# 10  11                           Arthur Weasley      Arthur             True
# ...

# %% [markdown]
# Selected and printed the SECOND AND THIRD columns of my data frame.

# %%
r = requests.get("https://harry-potter-api-en.onrender.com/characters")
df = pd.read_json("https://harry-potter-api-en.onrender.com/characters")
df[['nickname','hogwartsStudent']].head()
# Out:
#    nickname  hogwartsStudent
# 0     Harry             True
# 1  Hermione             True
# 2       Ron             True
# 3      Fred             True
# 4    George             True

# %% [markdown]
# Selected and printed the FIRST 4 rows of my data frame.

# %%
r = requests.get("https://harry-potter-api-en.onrender.com/characters")
df = pd.read_json("https://harry-potter-api-en.onrender.com/characters")
df.head (4)
# Out:
#    id              character  nickname  hogwartsStudent hogwartsHouse  \
# 0   1     Harry James Potter     Harry             True    Gryffindor
# 1   2  Hermione Jean Granger  Hermione             True    Gryffindor
# 2   3            Ron Weasley       Ron             True    Gryffindor
# 3   4           Fred Weasley      Fred             True    Gryffindor
#
#       interpretedBy                                              child  \
# 0  Daniel Radcliffe  [James Sirius Potter, Albus Severus Potter, Li...
# 1       Emma Watson       [Rose Granger-Weasley, Hugo Granger-Weasley]
# 2      Rupert Grint       [Rose Granger-Weasley, Hugo Granger-Weasley]
# 3      James Phelps                                                 []
#
#                                                image
# 0  https://raw.githubusercontent.com/fedeperin/ha...
# 1  https://raw.githubusercontent.com/fedeperin/ha...
# 2  https://raw.githubusercontent.com/fedeperin/ha...
# ...
